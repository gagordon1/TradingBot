# %%
#GOAL: Model decision to buy, sell or hold as a MDP

# %%
#Input X's - volume, moving averages,

# %%
#Ouput Y's - Softmax(buy, sell, hold)

# %%
def generate_y(timeseries):
    '''
    Given a vector of price data, generates optimal times to buy, sell or hold
    '''
