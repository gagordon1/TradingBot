# %%
from simulation import context, simulate
from datetime import datetime as dt
from DataAnalysis import DataAnalysis as DA
from moving_avgs1 import init, strat

# %%
start = dt(2020,4,27)
end = dt(2020,4,29)
timestep = '1m'
cash = 1500
con = simulate(init, strat, start, end, timestep, cash, market = 'NYSE')
dA = DA()
print(con)
dA.plot_dictionary(con.graph_data, buys = con.buys, sells = con.sells)
# Out:
# 20
# bought 1 shares of GT for 7.29$ at 2020-04-27  15:56:00
# bought 1 shares of GT for 7.29$ at 2020-04-27  15:57:00
# bought 1 shares of GT for 7.295$ at 2020-04-27  15:58:00
# sold 1 shares of GT for 7.61$ at 2020-04-28  09:34:00
# sold 1 shares of GT for 7.57$ at 2020-04-28  09:35:00
# sold 1 shares of GT for 7.6$ at 2020-04-28  09:36:00
# bought 1 shares of GT for 7.46$ at 2020-04-28  10:47:00
# bought 1 shares of GT for 7.45$ at 2020-04-28  10:48:00
# bought 1 shares of GT for 7.45$ at 2020-04-28  10:49:00
# bought 1 shares of GT for 7.44$ at 2020-04-28  10:50:00
# bought 1 shares of GT for 7.42$ at 2020-04-28  10:51:00
# bought 1 shares of GT for 7.41$ at 2020-04-28  10:52:00
# bought 1 shares of GT for 7.42$ at 2020-04-28  10:53:00
# bought 1 shares of GT for 7.42$ at 2020-04-28  10:54:00
# bought 1 shares of GT for 7.39$ at 2020-04-28  10:55:00
# bought 1 shares of GT for 7.38$ at 2020-04-28  10:56:00
# bought 1 shares of GT for 7.35$ at 2020-04-28  10:57:00
# ...
